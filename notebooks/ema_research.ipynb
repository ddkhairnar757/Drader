# %% [markdown]
# # EMA Crossover Research Notebook
#
# This notebook is a research sandbox. It should use the application modules for backtesting and experiment tracking, but not contain production logic.

# %%
import sys
from pathlib import Path

root = Path.cwd().parent
sys.path.insert(0, str(root))

from app.market_data.nifty_loader import HistoricalMarketDataLoader
from app.research.runner import BacktestRunner

data = HistoricalMarketDataLoader("data/nifty_sample.csv").load()
runner = BacktestRunner()
record = runner.run(
    strategy_name="ema_crossover",
    market_data=data,
    dataset="NIFTY_sample",
    timeframe="daily",
    notes="Research run",
    parameters={"fast_window": 9, "slow_window": 21, "fixed_size": 1},
)
print(record.experiment_id)
print(record.metrics)
from app.research.runner import BacktestRunner

data = HistoricalMarketDataLoader("data/nifty_sample.csv").load()
runner = BacktestRunner()
record = runner.run(
    strategy_name="ema_crossover",
    market_data=data,
    dataset="NIFTY_sample",
    timeframe="daily",
    notes="Research run",
    parameters={"fast_window": 9, "slow_window": 21, "fixed_size": 1},
)
print(record.experiment_id)
print(record.metrics)
